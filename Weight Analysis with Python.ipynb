# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\uncle\Google Drive\Data Analysis with Python\Weight management - Data.csv")
df
# Out:
#            Date  Days since September 14th, 2023  Weight in lbs Time of day  \
# 0    09-14-2022                                0          183.0         AM
# 1    09-15-2022                                1          183.0         AM
# 2    09-16-2022                                2          184.4          AM
# 3    09-17-2022                                3          182.6          PM
# 4    09-18-2022                                4          183.4          AM
# ..          ...                              ...            ...         ...
# 162  05-05-2023                              232          176.6          AM
# 163  05-08-2023                              235          176.2          AM
# 164  05-09-2023                              236          174.8          AM
# 165  05-10-2023                              237          172.8          AM
# 166  05-11-2023                              238          174.0          AM
#
#      Unnamed: 4               Unnamed: 5  Unnamed: 6
# ...

# %%
df = df[['Date', 'Days since September 14th, 2023','Weight in lbs', 'Time of day']]
df
# Out:
#            Date  Days since September 14th, 2023  Weight in lbs Time of day
# 0    09-14-2022                                0          183.0         AM
# 1    09-15-2022                                1          183.0         AM
# 2    09-16-2022                                2          184.4          AM
# 3    09-17-2022                                3          182.6          PM
# 4    09-18-2022                                4          183.4          AM
# ..          ...                              ...            ...         ...
# 162  05-05-2023                              232          176.6          AM
# 163  05-08-2023                              235          176.2          AM
# 164  05-09-2023                              236          174.8          AM
# 165  05-10-2023                              237          172.8          AM
# 166  05-11-2023                              238          174.0          AM
#
# [167 rows x 4 columns]

# %%
print(df.dtypes)
# Out:
# Date                                object
# Days since September 14th, 2023      int64
# Weight in lbs                      float64
# Time of day                         object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             167 non-null    object
#  1   Days since September 14th, 2023  167 non-null    int64
#  2   Weight in lbs                    167 non-null    float64
#  3   Time of day                      167 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.3+ KB
# None

# %%
lm = LinearRegression()

# %%
X = df[['Days since September 14th, 2023']]
Y = df[['Weight in lbs']]

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# array([182.54712213])

# %%
lm.coef_
# Out:
# array([[-0.03461875]])

# %%
Yhat = 182.54 + -0.03461875*x

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="Days since September 14th, 2023", y="Weight in lbs", data=df)
plt.ylim(165,200)
# Out:
# (165.0, 200.0)

# %%
lm.score(X, Y)
# Out:
# 0.782638253774053

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['Days since September 14th, 2023'], y=df['Weight in lbs'])
plt.show()

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [[182.54712213]
#  [182.51250338]
#  [182.47788463]
#  [182.44326588]]

# %%
Yhat=lm.predict(X)
print('The output of the next four predicted value is: ', Yhat[166:167])
# Out:
# The output of the next four predicted value is:  [[174.30785968]]

# %%
Date = df['Date']
Value = df['Weight in lbs']

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\uncle\AppData\Local\Temp\ipykernel_1528\936118274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Date"])
